# %%
import pandas as pd
import polars as pl

df = pl.read_parquet("/app/data/processed/AEP_hourly_processed.parquet")
df.head(5)
# Out:
# shape: (5, 15)
# ┌─────────────┬─────────┬─────────┬───────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ Datetime    ┆ AEP_MW  ┆ target  ┆ state ┆ … ┆ target_lag_ ┆ target_lag ┆ target_rol ┆ target_rol │
# │ ---         ┆ ---     ┆ ---     ┆ ---   ┆   ┆ 1           ┆ _24        ┆ l_mean_24  ┆ l_std_24   │
# │ datetime[μs ┆ f64     ┆ f64     ┆ str   ┆   ┆ ---         ┆ ---        ┆ ---        ┆ ---        │
# │ ]           ┆         ┆         ┆       ┆   ┆ f64         ┆ f64        ┆ f64        ┆ f64        │
# ╞═════════════╪═════════╪═════════╪═══════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 2004-10-02  ┆ 12260.0 ┆ 12260.0 ┆ AEP   ┆ … ┆ 13147.0     ┆ 12379.0    ┆ 14237.125  ┆ 1504.12627 │
# │ 01:00:00    ┆         ┆         ┆       ┆   ┆             ┆            ┆            ┆ 6          │
# │ 2004-10-02  ┆ 11672.0 ┆ 11672.0 ┆ AEP   ┆ … ┆ 12260.0     ┆ 11935.0    ┆ 14232.1666 ┆ 1510.69965 │
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
df.shape
# Out:
# (121273, 2)
